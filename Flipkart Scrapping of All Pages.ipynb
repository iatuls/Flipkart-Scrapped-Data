# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen as uReq
import logging
import pandas as pd

# %%
# url = 'https://www.flipkart.com/search?q=iphone+12&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=iphone+12%7CMobiles&requestId=4850e8db-c7a9-424b-9f8a-ec29e2c5d1fd&page=1'

# %%
# soup = BeautifulSoup(response,'html.parser')

# %%
# name = soup.find('div' , class_ = '_4rR01T').text

# %%
name
# Out:
# <div class="_4rR01T">APPLE iPhone 11 (Black, 128 GB)</div>

# %%
# products = soup.find_all('div', class_='_3pLy-c row')

# %%
products=[]
for i in range(1,11):
    url = f"https://www.flipkart.com/search?q=iphone+12&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=iphone+12%7CMobiles&requestId=4850e8db-c7a9-424b-9f8a-ec29e2c5d1fd&page={i}"
    response=requests.get(url)
    response=response.content
    soup = BeautifulSoup(response,'html.parser')
    products = soup.find_all('div', class_='_3pLy-c row')


    for product in products:

        Name = product.find('div' , class_ = '_4rR01T').text
        Price = product.find('div' , class_ = "_30jeq3 _1_WHN1").text
        Discount_per = product.find('div' , class_ = "_3Ay6Sb").text
        Discription = product.find('li' , class_ = "rgWa7D").text
        Rating_and_review_count = product.find('span' , class_ = "_2_R_DZ").text
        Delivery = product.find('div' , class_ = "_2Tpdn3").text
        Upto_this_off_on_exchange = product.find('div' , class_ = "_2ZdXDB").text
        print('Name:-', Name)
        print('Price is', Price)
        print('Discount Percentage is', Discount_per)
        print('Rating & reviewcount',Rating_and_review_count)
        print('Delivery Charges:-', Delivery)
        print('Exchange Offer:-', Upto_this_off_on_exchange)
        print('\n')
# Out:
# Name:- APPLE iPhone 12 (Black, 64 GB)
# Price is ₹53,999
# Discount Percentage is 9% off
# Rating & reviewcount 1,87,313 Ratings & 12,755 Reviews
# Delivery Charges:- Free delivery
# Exchange Offer:- Upto ₹23,000 Off on Exchange
#
#
# Name:- APPLE iPhone 12 (Purple, 64 GB)
# Price is ₹53,999
# Discount Percentage is 9% off
# Rating & reviewcount 1,87,313 Ratings & 12,755 Reviews
# Delivery Charges:- Free delivery
# Exchange Offer:- Upto ₹23,000 Off on Exchange
#
#
# Name:- APPLE iPhone 12 (Green, 64 GB)
# Price is ₹53,999
# Discount Percentage is 9% off
# Rating & reviewcount 1,87,313 Ratings & 12,755 Reviews
# Delivery Charges:- Free delivery
# Exchange Offer:- Upto ₹23,000 Off on Exchange
#
#
# Name:- APPLE iPhone 12 (Red, 128 GB)
# Price is ₹57,999
# Discount Percentage is 10% off
# Rating & reviewcount 1,87,313 Ratings & 12,755 Reviews
# Delivery Charges:- Free delivery
# Exchange Offer:- Upto ₹23,000 Off on Exchange
#
#
# Name:- APPLE iPhone 12 (White, 64 GB)
# Price is ₹53,999
# ...
